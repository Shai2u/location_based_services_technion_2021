# %% [markdown]
# # Ex 8 Dash Plotly Layout

# %% [markdown]
# # Dash Plotly Has 3 Main Components
# ## 1. Layout
# ## 2. Graphs/Objects
# ## 3. Callback (Layout + Plotly)
# <hr/>

# %% [markdown]
# ### <b>Part 1</b> Run Dashboards on Jupyter
# ### <b>Part 2</b> Designing a dashboard and Layout
# ### <b>Part 3</b> Insert the graphs that we want
# ### <b>Part 4</b> Create Basic Cllaback interaction
# ### <b>Part 5</b> Create two way interactions and add complexity
# ### <b>Part 6</b> Run Dashboards Stand Alone
# ### <b>Part 7</b> Deployment to Binder / Pythonanywhere
#
#
#
# Exercise is based on :
# https://github.com/plotly/jupyter-dash/blob/master/notebooks/getting_started.ipynb

# %%
from jupyter_dash import JupyterDash
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

# %% [markdown]
# ## Part 1 Running Dashbord in Jupyter

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([html.H1(['Hello World'])])
app.run_server(mode="jupyterlab",port=8060)

# %% [markdown]
# ## Part 2  Running Dashboard on Jupyter and Layout Design

# %%
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.H1(['Cell 1 1'])]),
            html.Td([html.H1(['Cell 1 2'])]),
            html.Td([html.H1(['Cell 1 3'])])
                ]),
        html.Tr([
            html.Td([html.H1(['Cell 2 1'])]),
            html.Td([html.H1(['Cell 2 2'])]),
            html.Td([html.H1(['Cell 2 3'])])
                ]),
        html.Tr([
            html.Td([html.H1(['Cell 3 1'])]),
            html.Td([html.H1(['Cell 3 2'])]),
            html.Td([html.H1(['Cell 3 3'])])
                ])
        
    ])
])
app.run_server(mode="jupyterlab",port=8060)

# %%
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.Div([html.H4(['Cell 1 1'])],id='c11',
                              style={'width':'300px','height':'200px','background-color':'hsl(0, 0%, 80%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c12',
                              style={'width':'300px','height':'200px','background-color':'hsl(60, 50%, 80%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c13',
                              style={'width':'300px','height':'200px','background-color':'hsl(60, 100%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([
            html.Td([html.Div([html.H4('Cell 1 1')],id='c21',
                              style={'width':'300px','height':'200px','background-color':'hsl(0, 0%, 60%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c22',
                              style={'width':'300px','height':'200px','background-color':'hsl(70, 50%, 80%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c23',
                              style={'width':'300px','height':'200px','background-color':'hsl(80, 100%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([
            html.Td([html.Div([html.H4('Cell 1 1')],id='c31',
                              style={'width':'300px','height':'200px','background-color':'hsl(0, 0%, 40%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c32',
                              style={'width':'300px','height':'200px','background-color':'hsl(80, 50%, 80%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c33',
                              style={'width':'300px','height':'200px','background-color':'hsl(90, 100%, 80%)','text-align': 'center'})])
                ])
        
    ])
])
app.run_server(mode="jupyterlab",port=8060)

# %% [markdown]
# ### Adding some style to the table

# %%
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.Div([html.H4(['Cell 1 1'])],id='c11',
                              style={'width':'625px','height':'200px','background-color':'hsl(0, 0%, 80%)','text-align': 'center'})],colSpan=2),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c13',
                              style={'width':'300px','height':'425px','background-color':'hsl(60, 100%, 80%)','text-align': 'center'})],rowSpan=2)
                ]),
        html.Tr([
            html.Td([html.Div([html.H4('Cell 1 1')],id='c21',
                              style={'width':'300px','height':'200px','background-color':'hsl(0, 0%, 60%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c22',
                              style={'width':'300px','height':'200px','background-color':'hsl(70, 50%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([
            html.Td([html.Div([html.H4('Cell 1 1')],id='c31',
                              style={'width':'300px','height':'200px','background-color':'hsl(0, 0%, 40%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c32',
                              style={'width':'300px','height':'200px','background-color':'hsl(80, 50%, 80%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c33',
                              style={'width':'300px','height':'200px','background-color':'hsl(90, 100%, 80%)','text-align': 'center'})])
                ])
        
    ])
])
app.run_server(mode="jupyterlab",port=8060)

# %% [markdown]
# ## more on HTML layout and dash-plotlyu layout:
# * https://www.tutorialspoint.com/html/html_tables.htm
# * https://dash.plotly.com/layout
# * https://www.youtube.com/watch?v=vqVwpL4bGKY

# %% [markdown]
# ## Part 3  Running Dashboard on Jupyter and Layout Design

# %%
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.Div([html.H4(['Cell 1 1'])],id='c11',
                              style={'width':'450px','height':'100px','background-color':'hsl(0, 0%, 80%)','text-align': 'center'})]),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c13',
                              style={'width':'450px','height':'100px','background-color':'hsl(60, 100%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([
            html.Td([html.Div([html.H4('Cell 1 1')],id='c21',
                              style={'width':'450px','height':'500px','background-color':'hsl(0, 0%, 60%)','text-align': 'center'})],rowSpan=2),
            html.Td([html.Div([html.H4('Cell 1 1')],id='c22',
                              style={'width':'450px','height':'225px','background-color':'hsl(70, 50%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([html.Td([html.Div([html.H4('Cell 3 3')],id='c33',
                              style={'width':'450px','height':'225px','background-color':'hsl(90, 100%, 80%)','text-align': 'center','margin-left':11})])
                ])
        
    ])
])
app.run_server(mode="jupyterlab",port=8060)

# %%
df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')

# %%
df
# Out:
#       Country Name                                     Indicator Name  Year  \
# 0       Arab World                Agriculture, value added (% of GDP)  1962
# 1       Arab World             CO2 emissions (metric tons per capita)  1962
# 2       Arab World  Domestic credit provided by financial sector (...  1962
# 3       Arab World        Electric power consumption (kWh per capita)  1962
# 4       Arab World       Energy use (kg of oil equivalent per capita)  1962
# ...            ...                                                ...   ...
# 36955     Zimbabwe                   Industry, value added (% of GDP)  2007
# 36956     Zimbabwe                 Inflation, GDP deflator (annual %)  2007
# 36957     Zimbabwe            Life expectancy at birth, total (years)  2007
# 36958     Zimbabwe  Population density (people per sq. km of land ...  2007
# 36959     Zimbabwe             Services, etc., value added (% of GDP)  2007
#
#            Value
# 0            NaN
# 1       0.760996
# ...

# %%
available_indicators = df['Indicator Name'].unique() #Print avilable indicators
available_indicators
# Out:
# array(['Agriculture, value added (% of GDP)',
#        'CO2 emissions (metric tons per capita)',
#        'Domestic credit provided by financial sector (% of GDP)',
#        'Electric power consumption (kWh per capita)',
#        'Energy use (kg of oil equivalent per capita)',
#        'Exports of goods and services (% of GDP)',
#        'Fertility rate, total (births per woman)',
#        'GDP growth (annual %)',
#        'Imports of goods and services (% of GDP)',
#        'Industry, value added (% of GDP)',
#        'Inflation, GDP deflator (annual %)',
#        'Life expectancy at birth, total (years)',
#        'Population density (people per sq. km of land area)',
#        'Services, etc., value added (% of GDP)'], dtype=object)

# %%
df1 = df[df['Year']==2007].copy()
df2 = df[df['Indicator Name']=='GDP growth (annual %)'].copy()
df3 = df[df['Indicator Name']=='Life expectancy at birth, total (years)'].copy()
df1X = df1.query("`Indicator Name`=='GDP growth (annual %)'")
df1Y = df1.query("`Indicator Name`=='Life expectancy at birth, total (years)'")

fig1, fig2, fig3 = [px.scatter(df1X,x=df1X['Value'],y=df1Y['Value'],template='plotly_white',hover_data=['Country Name'],labels={'x':'GDP growth (annual %)','y':'Life expectancy at birth, total (years)'}),
                    px.line(df2.query('`Country Name`=="Israel"'),x="Year", y="Value", color='Country Name',template='plotly_white'),
                    px.line(df3.query('`Country Name`=="Israel"'),x="Year", y="Value", color='Country Name',template='plotly_white')]
fig1.update_layout(height=500,showlegend=False)
fig2.update_layout(height=225)
fig3.update_layout(height=225)

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.Div([
                dcc.Dropdown(
                id='crossfilter-xaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                        value='GDP growth (annual %)'),
                dcc.RadioItems(
                    id='crossfilter-xaxis-type',
                    options=[{'label': 'Linear', 'value': 'Linear'},
                             {'label': 'Log', 'value': 'Log'}],
                    value='Linear',
                    labelStyle={'display': 'inline-block'}
                ) 
            ],id='c11',
                              style={'width':'450px'})]),
            html.Td([html.Div([
                dcc.Dropdown(
                id='crossfilter-yaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                        value='Life expectancy at birth, total (years)'),
                dcc.RadioItems(
                    id='crossfilter-yaxis-type',
                    options=[{'label': 'Linear', 'value': 'Linear'},
                             {'label': 'Log', 'value': 'Log'}],
                    value='Linear',
                    labelStyle={'display': 'inline-block'}
                )
                
            ],id='c13',
                              style={'width':'450px'})])
                ]),
        html.Tr([
            
            html.Td([html.Div([
                dcc.Graph(figure=fig1,id='crossfilter-indicator-scatter',hoverData={'points': [{'customdata': ['Israel']}]}),
                html.Div(dcc.Slider(
                    id='crossfilter-year--slider',
                    min=df['Year'].min(),
                    max=df['Year'].max(),
                    value=df['Year'].max(),
                    marks={str(year): str(year) for year in df['Year'].unique()},step=None
                ), style={'width': '100%', 'padding': '0px 20px 20px 20px'})
            ],id='c21',style={'width':'450px','height':'500px','background-color':'hsl(0, 0%, 60%)','text-align': 'center'})],rowSpan=2),
            html.Td([html.Div([dcc.Graph(figure=fig2,id='x-time-series')],id='c22',
                              style={'width':'450px','height':'225px','background-color':'hsl(70, 50%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([html.Td([html.Div([dcc.Graph(figure=fig3,id='y-time-series')],id='c33',
                              style={'width':'450px','height':'225px','background-color':'hsl(90, 100%, 80%)','text-align': 'center','margin-left':11})])
                ])
        
    ])
])




app.run_server(mode="jupyterlab",port=8060)

# %% [markdown]
# ## Part 4 Create Basic Cllaback interaction

# %%
df.head()
# Out:
#   Country Name                                     Indicator Name  Year  \
# 0   Arab World                Agriculture, value added (% of GDP)  1962
# 1   Arab World             CO2 emissions (metric tons per capita)  1962
# 2   Arab World  Domestic credit provided by financial sector (...  1962
# 3   Arab World        Electric power consumption (kWh per capita)  1962
# 4   Arab World       Energy use (kg of oil equivalent per capita)  1962
#
#        Value
# 0        NaN
# 1   0.760996
# 2  18.168690
# 3        NaN
# 4        NaN

# %%
df1 = df[df['Year']==2007].copy()
df2 = df[df['Indicator Name']=='GDP growth (annual %)'].copy()
df3 = df[df['Indicator Name']=='Life expectancy at birth, total (years)'].copy()
df1X = df1.query("`Indicator Name`=='GDP growth (annual %)'")
df1Y = df1.query("`Indicator Name`=='Life expectancy at birth, total (years)'")

fig1, fig2, fig3 = [px.scatter(df1X,x=df1X['Value'],y=df1Y['Value'],template='plotly_white',hover_data=['Country Name'],labels={'x':'GDP growth (annual %)','y':'Life expectancy at birth, total (years)'}),
                    px.line(df2.query('`Country Name`=="Israel"'),x="Year", y="Value", color='Country Name',template='plotly_white'),
                    px.line(df3.query('`Country Name`=="Israel"'),x="Year", y="Value", color='Country Name',template='plotly_white')]
fig1.update_layout(height=500,showlegend=False)
fig2.update_layout(height=225)
fig3.update_layout(height=225)

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.Div([
                dcc.Dropdown(
                id='crossfilter-xaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                        value='GDP growth (annual %)'),
                dcc.RadioItems(
                    id='crossfilter-xaxis-type',
                    options=[{'label': 'Linear', 'value': 'Linear'},
                             {'label': 'Log', 'value': 'Log'}],
                    value='Linear',
                    labelStyle={'display': 'inline-block'}
                ) 
            ],id='c11',
                              style={'width':'450px'})]),
            html.Td([html.Div([
                dcc.Dropdown(
                id='crossfilter-yaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                        value='Life expectancy at birth, total (years)'),
                dcc.RadioItems(
                    id='crossfilter-yaxis-type',
                    options=[{'label': 'Linear', 'value': 'Linear'},
                             {'label': 'Log', 'value': 'Log'}],
                    value='Linear',
                    labelStyle={'display': 'inline-block'}
                )
                
            ],id='c13',
                              style={'width':'450px'})])
                ]),
        html.Tr([
            
            html.Td([html.Div([
                dcc.Graph(figure=fig1,id='crossfilter-indicator-scatter',hoverData={'points': [{'customdata': ['Israel']}]}),
                html.Div(dcc.Slider(
                    id='crossfilter-year--slider',
                    min=df['Year'].min(),
                    max=df['Year'].max(),
                    value=df['Year'].max(),
                    marks={str(year): str(year) for year in df['Year'].unique()},step=None
                ), style={'width': '100%', 'padding': '0px 20px 20px 20px'})
            ],id='c21',style={'width':'450px','height':'500px','background-color':'hsl(0, 0%, 60%)','text-align': 'center'})],rowSpan=2),
            html.Td([html.Div([dcc.Graph(figure=fig2,id='x-time-series')],id='c22',
                              style={'width':'450px','height':'225px','background-color':'hsl(70, 50%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([html.Td([html.Div([dcc.Graph(figure=fig3,id='y-time-series')],id='c33',
                              style={'width':'450px','height':'225px','background-color':'hsl(90, 100%, 80%)','text-align': 'center','margin-left':11})])
                ])
        
    ])
])


@app.callback(
    
    [Output('crossfilter-indicator-scatter', 'figure'),Output('x-time-series', 'figure'),Output('y-time-series', 'figure')],
    [Input('crossfilter-xaxis-column','value'),
     Input('crossfilter-yaxis-column','value'),
     Input('crossfilter-year--slider','value'),
     Input('crossfilter-xaxis-type','value'),
     Input('crossfilter-yaxis-type','value')
    ])
def update_graph(xaxis_column_name,yaxis_column_name,year_value,xaxis_type, yaxis_type):
    
    colX = df[(df['Indicator Name']==xaxis_column_name) & (df['Year']==year_value)].copy()
    colY = df[(df['Indicator Name']==yaxis_column_name) & (df['Year']==year_value)].copy()                 
    fig1 = px.scatter(colX,x=colX['Value'], y=colY['Value'],template='plotly_white',labels={'Value':xaxis_column_name,'y':yaxis_column_name},hover_data=['Country Name'])
    fig1.update_layout(showlegend=False, height=500,hovermode='closest')
    
    xType ='linear'
    yType = 'linear'
    if xaxis_type=='Log':
        xType='log'
    if yaxis_type=='Log':
        yType='log'
        
    fig1.update_xaxes(type=xType) 
    fig1.update_yaxes(type=yType)

    df2 = df[df['Indicator Name']==xaxis_column_name].copy()
    df2 = df2.query(f'`Country Name`=="Israel"')
    title_ = '<b>{}</b><br>{}'.format('Israel', xaxis_column_name)
    fig2 = px.scatter(df2,y=df2['Value'], x='Year',template='plotly_white',labels={'Value':xaxis_column_name},title='Israel')
    fig2.update_layout(height=325)
    fig2.update_xaxes(type=xType) 
    fig2.update_yaxes(type=yType) 
    
    df3 = df[df['Indicator Name']==yaxis_column_name].copy()
    df3 = df3.query(f'`Country Name`=="Israel"')
    fig3 = px.scatter(df3,y=df3['Value'], x='Year',template='plotly_white',labels={'Value':yaxis_column_name})
    fig3.update_layout(height=325)   
    fig3.update_xaxes(type=xType) 
    fig3.update_yaxes(type=yType)    
    return [fig1,fig2,fig3]





app.run_server(mode="jupyterlab",port=8060)

# %%
df1 = df[df['Year']==2007].copy()
df2 = df[df['Indicator Name']=='GDP growth (annual %)'].copy()
df3 = df[df['Indicator Name']=='Life expectancy at birth, total (years)'].copy()
df1X = df1.query("`Indicator Name`=='GDP growth (annual %)'")
df1Y = df1.query("`Indicator Name`=='Life expectancy at birth, total (years)'")

fig1, fig2, fig3 = [px.scatter(df1X,x=df1X['Value'],y=df1Y['Value'],template='plotly_white',hover_data=['Country Name'],labels={'x':'GDP growth (annual %)','y':'Life expectancy at birth, total (years)'}),
                    px.line(df2.query('`Country Name`=="Israel"'),x="Year", y="Value", color='Country Name',template='plotly_white'),
                    px.line(df3.query('`Country Name`=="Israel"'),x="Year", y="Value", color='Country Name',template='plotly_white')]
fig1.update_layout(height=500,showlegend=False)
fig2.update_layout(height=225)
fig3.update_layout(height=225)

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
server= app.server
app.layout = html.Div([
    html.Table([
        html.Tr([
            html.Td([html.Div([
                dcc.Dropdown(
                id='crossfilter-xaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                        value='GDP growth (annual %)'),
                dcc.RadioItems(
                    id='crossfilter-xaxis-type',
                    options=[{'label': 'Linear', 'value': 'Linear'},
                             {'label': 'Log', 'value': 'Log'}],
                    value='Linear',
                    labelStyle={'display': 'inline-block'}
                ) 
            ],id='c11',
                              style={'width':'450px'})]),
            html.Td([html.Div([
                dcc.Dropdown(
                id='crossfilter-yaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                        value='Life expectancy at birth, total (years)'),
                dcc.RadioItems(
                    id='crossfilter-yaxis-type',
                    options=[{'label': 'Linear', 'value': 'Linear'},
                             {'label': 'Log', 'value': 'Log'}],
                    value='Linear',
                    labelStyle={'display': 'inline-block'}
                )
                
            ],id='c13',
                              style={'width':'450px'})])
                ]),
        html.Tr([
            
            html.Td([html.Div([
                dcc.Graph(figure=fig1,id='crossfilter-indicator-scatter',hoverData={'points': [{'customdata': ['Israel']}]}),
                html.Div(dcc.Slider(
                    id='crossfilter-year--slider',
                    min=df['Year'].min(),
                    max=df['Year'].max(),
                    value=df['Year'].max(),
                    marks={str(year): str(year) for year in df['Year'].unique()},step=None
                ), style={'width': '100%', 'padding': '0px 20px 20px 20px'})
            ],id='c21',style={'width':'450px','height':'500px','background-color':'hsl(0, 0%, 60%)','text-align': 'center'})],rowSpan=2),
            html.Td([html.Div([dcc.Graph(figure=fig2,id='x-time-series')],id='c22',
                              style={'width':'450px','height':'225px','background-color':'hsl(70, 50%, 80%)','text-align': 'center'})])
                ]),
        html.Tr([html.Td([html.Div([dcc.Graph(figure=fig3,id='y-time-series')],id='c33',
                              style={'width':'450px','height':'225px','background-color':'hsl(90, 100%, 80%)','text-align': 'center','margin-left':11})])
                ])
        
    ])
])


@app.callback(
    
    [Output('crossfilter-indicator-scatter', 'figure')],
    [Input('crossfilter-xaxis-column','value'),
     Input('crossfilter-yaxis-column','value'),
     Input('crossfilter-year--slider','value'),
     Input('crossfilter-xaxis-type','value'),
     Input('crossfilter-yaxis-type','value')
    ])
def update_graph(xaxis_column_name,yaxis_column_name,year_value,xaxis_type, yaxis_type):
    
    colX = df[(df['Indicator Name']==xaxis_column_name) & (df['Year']==year_value)].copy()
    colY = df[(df['Indicator Name']==yaxis_column_name) & (df['Year']==year_value)].copy()                 
    fig1 = px.scatter(colX,x=colX['Value'], y=colY['Value'],template='plotly_white',labels={'Value':xaxis_column_name,'y':yaxis_column_name},hover_data=['Country Name'])
    fig1.update_layout(showlegend=False, height=500,hovermode='closest')
    
    xType ='linear'
    yType = 'linear'
    if xaxis_type=='Log':
        xType='log'
    if yaxis_type=='Log':
        yType='log'
        
    fig1.update_xaxes(type=xType) 
    fig1.update_yaxes(type=yType)
    return [fig1]

@app.callback(
    [Output('x-time-series', 'figure')],
    [Input('crossfilter-xaxis-column','value'),
     Input('crossfilter-indicator-scatter','hoverData'),
     Input('crossfilter-xaxis-type','value'),
     Input('crossfilter-yaxis-type','value')])
def update_graph_X(xaxis_column_name,hover_data,xaxis_type, yaxis_type):
    hoverData = hover_data['points'][0]['customdata'][0]
    xType ='linear'
    yType = 'linear'
    if xaxis_type=='Log':
        xType='log'
    if yaxis_type=='Log':
        yType='log'
    df2 = df[df['Indicator Name']==xaxis_column_name].copy()
    df2 = df2.query(f'`Country Name`=="{hoverData}"')
    
    title_ = '<b>{}</b><br>{}'.format(hoverData, xaxis_column_name)
    fig2 = px.scatter(df2,y=df2['Value'], x='Year',template='plotly_white',labels={'Value':xaxis_column_name},title=title_)
    fig2.update_layout(height=325)
    fig2.update_xaxes(type=xType) 
    fig2.update_yaxes(type=yType) 
    return [fig2]

@app.callback(
    [Output('y-time-series', 'figure')],
    [Input('crossfilter-yaxis-column','value'),
     Input('crossfilter-indicator-scatter','hoverData'),
     Input('crossfilter-xaxis-type','value'),
     Input('crossfilter-yaxis-type','value')])
def update_graph_Y(yaxis_column_name,hover_data,xaxis_type, yaxis_type):
    hoverData = hover_data['points'][0]['customdata'][0]
    xType ='linear'
    yType = 'linear'
    if xaxis_type=='Log':
        xType='log'
    if yaxis_type=='Log':
        yType='log'    
    df3 = df[df['Indicator Name']==yaxis_column_name].copy()
    df3 = df3.query(f'`Country Name`=="{hoverData}"')
    fig3 = px.scatter(df3,y=df3['Value'], x='Year',template='plotly_white',labels={'Value':yaxis_column_name})
    fig3.update_layout(height=325)   
    fig3.update_xaxes(type=xType) 
    fig3.update_yaxes(type=yType) 
    return [fig3]
app.run_server(mode="jupyterlab",port=8060)

# %%
df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')
available_indicators = df['Indicator Name'].unique()

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# Create server variable with Flask server object for use with gunicorn

server= app.server

app.layout = html.Div([
    html.Div([

        html.Div([
            dcc.Dropdown(
                id='crossfilter-xaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                value='Fertility rate, total (births per woman)'
            ),
            dcc.RadioItems(
                id='crossfilter-xaxis-type',
                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
                value='Linear',
                labelStyle={'display': 'inline-block'}
            )
        ],
        style={'width': '49%', 'display': 'inline-block'}),

        html.Div([
            dcc.Dropdown(
                id='crossfilter-yaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                value='Life expectancy at birth, total (years)'
            ),
            dcc.RadioItems(
                id='crossfilter-yaxis-type',
                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
                value='Linear',
                labelStyle={'display': 'inline-block'}
            )
        ], style={'width': '49%', 'float': 'right', 'display': 'inline-block'})
    ], style={
        'borderBottom': 'thin lightgrey solid',
        'backgroundColor': 'rgb(250, 250, 250)',
        'padding': '10px 5px'
    }),

    html.Div([
        dcc.Graph(
            id='crossfilter-indicator-scatter',
            hoverData={'points': [{'customdata': 'Japan'}]}
        )
    ], style={'width': '49%', 'display': 'inline-block', 'padding': '0 20'}),
    html.Div([
        dcc.Graph(id='x-time-series'),
        dcc.Graph(id='y-time-series'),
    ], style={'display': 'inline-block', 'width': '49%'}),

    html.Div(dcc.Slider(
        id='crossfilter-year--slider',
        min=df['Year'].min(),
        max=df['Year'].max(),
        value=df['Year'].max(),
        marks={str(year): str(year) for year in df['Year'].unique()},
        step=None
    ), style={'width': '49%', 'padding': '0px 20px 20px 20px'})
])


@app.callback(
    dash.dependencies.Output('crossfilter-indicator-scatter', 'figure'),
    [dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-xaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-type', 'value'),
     dash.dependencies.Input('crossfilter-year--slider', 'value')])
def update_graph(xaxis_column_name, yaxis_column_name,
                 xaxis_type, yaxis_type,
                 year_value):
    dff = df[df['Year'] == year_value]

    return {
        'data': [dict(
            x=dff[dff['Indicator Name'] == xaxis_column_name]['Value'],
            y=dff[dff['Indicator Name'] == yaxis_column_name]['Value'],
            text=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
            customdata=dff[dff['Indicator Name'] == yaxis_column_name]['Country Name'],
            mode='markers',
            marker={
                'size': 25,
                'opacity': 0.7,
                'color': 'orange',
                'line': {'width': 2, 'color': 'purple'}
            }
        )],
        'layout': dict(
            xaxis={
                'title': xaxis_column_name,
                'type': 'linear' if xaxis_type == 'Linear' else 'log'
            },
            yaxis={
                'title': yaxis_column_name,
                'type': 'linear' if yaxis_type == 'Linear' else 'log'
            },
            margin={'l': 40, 'b': 30, 't': 10, 'r': 0},
            height=450,
            hovermode='closest'
        )
    }


def create_time_series(dff, axis_type, title):
    return {
        'data': [dict(
            x=dff['Year'],
            y=dff['Value'],
            mode='lines+markers'
        )],
        'layout': {
            'height': 225,
            'margin': {'l': 20, 'b': 30, 'r': 10, 't': 10},
            'annotations': [{
                'x': 0, 'y': 0.85, 'xanchor': 'left', 'yanchor': 'bottom',
                'xref': 'paper', 'yref': 'paper', 'showarrow': False,
                'align': 'left', 'bgcolor': 'rgba(255, 255, 255, 0.5)',
                'text': title
            }],
            'yaxis': {'type': 'linear' if axis_type == 'Linear' else 'log'},
            'xaxis': {'showgrid': False}
        }
    }


@app.callback(
    dash.dependencies.Output('x-time-series', 'figure'),
    [dash.dependencies.Input('crossfilter-indicator-scatter', 'hoverData'),
     dash.dependencies.Input('crossfilter-xaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-xaxis-type', 'value')])
def update_y_timeseries(hoverData, xaxis_column_name, axis_type):
    country_name = hoverData['points'][0]['customdata']
    dff = df[df['Country Name'] == country_name]
    dff = dff[dff['Indicator Name'] == xaxis_column_name]
    title = '<b>{}</b><br>{}'.format(country_name, xaxis_column_name)
    return create_time_series(dff, axis_type, title)


@app.callback(
    dash.dependencies.Output('y-time-series', 'figure'),
    [dash.dependencies.Input('crossfilter-indicator-scatter', 'hoverData'),
     dash.dependencies.Input('crossfilter-yaxis-column', 'value'),
     dash.dependencies.Input('crossfilter-yaxis-type', 'value')])
def update_x_timeseries(hoverData, yaxis_column_name, axis_type):
    dff = df[df['Country Name'] == hoverData['points'][0]['customdata']]
    dff = dff[dff['Indicator Name'] == yaxis_column_name]
    return create_time_series(dff, axis_type, yaxis_column_name)

# %%
app.run_server(mode="jupyterlab",port=8060)

# %% [markdown]
# ## Practical Examples!

# %%
from IPython.display import IFrame

# %% [markdown]
# https://dash-gallery.plotly.host/Portal/

# %%
    IFrame('https://dash-gallery.plotly.host/Portal/', width=1200, height=800)
# Out:
#         <iframe
#             width="1200"
#             height="800"
#             src="https://dash-gallery.plotly.host/Portal/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Implementing In Binder

# %% [markdown]
# 1. Open a github account
# 2. Create a repository
# 3. Upload your files
# 4. create a requierments.txt file
# 5. https://mybinder.org follow instructions
